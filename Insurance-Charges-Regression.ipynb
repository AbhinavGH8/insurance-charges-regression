# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-7c09beca-c405-4b67-bcd3-0fb900c0267d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7c09beca-c405-4b67-bcd3-0fb900c0267d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
insurance_data=pd.read_csv('insurance.csv')

# %%
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
insurance_data.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
insurance_data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
insurance_data.shape
# Out:
# (1338, 7)

# %%
insurance_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insurance_data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Distribution of Age Value
sns.set()
plt.figure(figsize=(3,3))
sns.histplot(insurance_data['age'])
plt.title("Age Distribution Graph")
# Out:
# Text(0.5, 1.0, 'Age Distribution Graph')

# %%
#Gender Column
plt.figure(figsize=(3,3))
sns.countplot(x="sex",data=insurance_data,color="Yellow")
plt.title("Gender Distribution Graph")
plt.show()

# %%
#BMI Distribution
plt.figure(figsize=(3,3))
sns.histplot(insurance_data["bmi"],color="red")
plt.title("BMI Distribution")
# Out:
# Text(0.5, 1.0, 'BMI Distribution')

# %%
#Children Distribution
plt.figure(figsize=(3,3))
sns.countplot(x="children",data=insurance_data,color="purple")
plt.title("Children Distribution")
plt.show()

# %%
#Distribution of Charge Values
sns.set()
plt.figure(figsize=(3,3))
sns.distplot(insurance_data["charges"],color="green")
plt.title("Charge Distribution")
plt.show()
# Out:
# /tmp/ipython-input-16-1749234012.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(insurance_data["charges"],color="green")

# %%
insurance_data['sex'].value_counts()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %%
insurance_data["smoker"].value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %%
insurance_data["region"].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
insurance_data.replace({"sex":{"male":0,"female":1}},inplace=True)
insurance_data.replace({"smoker":{"yes":0,"no":1}},inplace=True)
insurance_data.replace({"region":{"southeast":0,"southwest":1,"northwest":2,"northeast":3}},inplace=True)

# %%
insurance_data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    1  27.900         0       0       1  16884.92400
# 1   18    0  33.770         1       1       0   1725.55230
# 2   28    0  33.000         3       1       0   4449.46200
# 3   33    0  22.705         0       1       2  21984.47061
# 4   32    0  28.880         0       1       2   3866.85520

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn import metrics

# %%
x=insurance_data.drop(columns="charges",axis=1)
print(x)
y=insurance_data["charges"]
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       0       1
# 1      18    0  33.770         1       1       0
# 2      28    0  33.000         3       1       0
# 3      33    0  22.705         0       1       2
# 4      32    0  28.880         0       1       2
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    0  30.970         3       1       2
# 1334   18    1  31.920         0       1       3
# 1335   18    1  36.850         0       1       0
# 1336   21    1  25.800         0       1       1
# 1337   61    1  29.070         0       0       2
#
# [1338 rows x 6 columns]

# %%
print(y)
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (1338, 6) (1070, 6) (268, 6)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print('Accurracy of  linear regression classifier on training set:{:.2f}'.format(model.score(x_train,y_train)))
# Out:
# Accurracy of  linear regression classifier on training set:0.75

# %%
print('Accurracy of  linear regression classifier on testing set:{:.2f}'.format(model.score(x_test,y_test)))
# Out:
# Accurracy of  linear regression classifier on testing set:0.75

# %%
input_data=(31,1,25.74,0,1,0)
# changing the input data into a numpy array
input_data_as_numpy_array=np.array(input_data)

#reshape the array
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)
prediction=model.predict(input_data_reshaped)
print(prediction)

print('The insurance is USD',prediction[0])
# Out:
# [3632.02043291]
# The insurance is USD 3632.0204329083863
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
